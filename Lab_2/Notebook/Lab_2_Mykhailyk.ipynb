# %% [markdown]
# Створений env в anaconda за допомогою "conda env list":
# ![image1.png](attachment:5bf3e558-09b5-48a9-9feb-7be9f5e7a84c.png)

# %% [markdown]
# Інфо:
# ![image2.png](attachment:08a607b5-1b03-4ad9-82d1-2e2c99e1a236.png)

# %% [markdown]
# Активування env та скачування notebook:
# ![image3.png](attachment:22e74383-273f-40ea-9d03-c9afb52ff417.png)

# %% [markdown]
# Запущений Jupiter Notebook:
# ![image4.png](attachment:134e3162-1adc-424b-9928-0603808dc65b.png)
